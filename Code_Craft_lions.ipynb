# %% [markdown]
# <a href="https://colab.research.google.com/github/walkerjian/DailyCode/blob/main/Code_Craft_lions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Problem:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Solution:
# To determine if the points (2,1), (5,7), and (11,18) lie on a straight line without drawing, we can check if the slopes between each pair of points are the same. If they are, then the points are collinear and lie on the same straight line.
#
# The slope between two points $(x_1, y_1)$ and $(x_2, y_2)$ is given by:
#
# $
# m = \frac{y_2 - y_1}{x_2 - x_1}
# $
#
# We need to calculate the slopes between (2,1) & (5,7) and between (5,7) & (11,18), and compare them.
#
# For the third point (20, y), we can substitute $ x = 20 $ into the equation of the line determined by the first two points and solve for $ y $.
#
# Similarly, for the point (x, 21), we can substitute $ y = 21 $ into the equation of the line and solve for $ x $.
#
# Let's perform these calculations now.
#
# The calculations show that the points (2,1), (5,7), and (11,18) do not lie on the same straight line because the slopes between the first two points and the last two points are not equal.
#
# The equation of the straight line that would pass through the points (2,1) and (5,7) is:
#
# $ y - 1 = 2(x - 2) $
#
# Substituting $ x = 20 $ into this equation, we find that the value of $ y $ would be 37. This means that if the straight line drawn through (2,1) and (5,7) was extended, it would pass through the point (20,37), not (20, y) as given in the third question. So $ y $ stands for 37 in this context.
#
# For the point (x, 21), substituting $ y = 21 $ into the equation of the line gives us an $ x $-value of 12. Hence, the point (12, 21) lies on the same line.
#
# In conclusion, the points are not collinear, the point where $ x = 20 $ would have $ y = 37 $ on the line through the first two points, and the point where $ y = 21 $ would have $ x = 12 $ on the same line.
#
# To find the functional form of the line passing through the first two points (2,1) and (5,7), we'll use the point-slope form of a line equation and then rearrange it to the slope-intercept form, $ y = mx + b $, where $ m $ is the slope and $ b $ is the y-intercept.
#
# We've already calculated the slope $ m = 2 $, and to find $ b $, we can use one of the points. Let's use (2,1):
#
# $ 1 = 2(2) + b $
#
# Solving for $ b $, we get:
#
# $ b = 1 - 4 $
# $ b = -3 $
#
# So the equation of the line is $ y = 2x - 3 $.
#
# Now let's check if the third point (11,18) lies on this line by plugging the x-value of the third point into the equation and seeing if we get the corresponding y-value.
#
# After that, we'll substitute $ y = 21 $ into the equation to solve for $ x $. Let's calculate these values.
#
# The functional form of the line passing through the first two points is $ y = 2x - 3 $.
#
# Upon checking the third point (11,18), it does not lie on this line, as predicted.
#
# Substituting $ y = 21 $ into the line equation, we find that $ x $ is 12. Therefore, the point (12, 21) lies on the line described by the equation $ y = 2x - 3 $.
